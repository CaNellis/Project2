# %% [markdown]
# ### Step 2: Data Cleaning

# %%
# import dependencies
import pandas as pd
import numpy as np
import math

# %%
#import and read csv file
my_file="gssInitialData.csv"
df=pd.read_csv(my_file)

# %%
# view shape of dataset
df.shape
# Out:
# (24350, 12)

# %%
# observe first few rows of dataset
df.head()
# Out:
#    Year Health Condition General happiness      U.S. Region          Income  \
# 0  2000        Excellent      Pretty happy  W. sou. central   $8000 to 9999
# 1  2000             Fair      Pretty happy  W. sou. central   $8000 to 9999
# 2  2000             Good      Pretty happy  W. sou. central  Not applicable
# 3  2000   Not applicable        Very happy  W. sou. central  Not applicable
# 4  2000   Not applicable      Pretty happy  W. sou. central  Not applicable
#
#     Race     Sex  Highest Degree Age Marital status       Work Status  ID
# 0  White    Male        Bachelor  26  Never married  Working fulltime   1
# 1  White  Female     High school  48       Divorced  Working fulltime   2
# 2  White  Female     High school  67        Widowed     Keeping house   3
# 3  White  Female     High school  39  Never married  Working fulltime   4
# 4  White  Female  Junior college  25       Divorced  Working fulltime   5

# %%
# view data types
df.dtypes
# Out:
# Year                  int64
# Health Condition     object
# General happiness    object
# U.S. Region          object
# Income               object
# Race                 object
# Sex                  object
# Highest Degree       object
# Age                  object
# Marital status       object
# Work Status          object
# ID                    int64
# dtype: object

# %%
# Note: In Excel, the Find Replace tool was used to replace any cells contianing "Not applicable" to "NaN"

# %%
# Quantify happiness response
dfclean = df.replace("Pretty happy", 10)
dfclean2 = dfclean.replace("Very happy", 5)
dfclean3 = dfclean2.replace("Not too happy", 0)

# drop all types of no answer responses
dfclean4 = dfclean3[dfclean3 != "Not applicable"]
dfclean5 = dfclean4[dfclean4 != "No answer"]
dfclean6 = dfclean5[dfclean5 != "Don't know"]
dfclean7 = dfclean6[dfclean6 != "Refused"] 
dfclean8 = dfclean7.dropna()

# convert happiness responses to numbers
dfclean8["General happiness"] = pd.to_numeric(dfclean8["General happiness"])

dfclean8
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Year Health Condition  General happiness      U.S. Region  \
# 0      2000        Excellent                 10  W. sou. central
# 1      2000             Fair                 10  W. sou. central
# 5      2000             Good                 10  W. sou. central
# 6      2000             Good                  5  W. sou. central
# 7      2000             Good                 10  W. sou. central
# 8      2000        Excellent                 10  W. sou. central
# 11     2000             Good                 10  W. sou. central
# 12     2000             Good                 10  W. sou. central
# 13     2000        Excellent                  5  W. sou. central
# 14     2000        Excellent                 10  W. sou. central
# 18     2000             Good                 10  W. sou. central
# 23     2000             Good                 10  W. sou. central
# 33     2000             Fair                 10  W. sou. central
# 34     2000             Good                  5  W. sou. central
# 35     2000             Good                  0  W. sou. central
# 38     2000             Good                 10  W. sou. central
# 40     2000             Fair                 10  W. sou. central
# 41     2000        Excellent                  5  W. sou. central
# 42     2000        Excellent                 10  W. sou. central
# 45     2000             Fair                 10  W. sou. central
# 46     2000        Excellent                  5  W. sou. central
# 48     2000        Excellent                  5  W. sou. central
# 49     2000             Good                 10  W. sou. central
# 50     2000             Good                 10  W. sou. central
# 51     2000        Excellent                 10  W. sou. central
# 52     2000        Excellent                  5  W. sou. central
# 54     2000        Excellent                 10  W. sou. central
# 56     2000             Good                  5  W. sou. central
# 57     2000        Excellent                 10  W. sou. central
# 58     2000             Good                 10  W. sou. central
# ...     ...              ...                ...              ...
# 24238  2016             Good                  5  E. nor. central
# 24271   $5000 to 5999  Black  Female  Lt high school  55      Separated
# 24279  $10000 - 14999  White  Female     High school  23       Divorced
# 24287        Lt $1000  Black  Female     High school  54       Divorced
# 24291  $10000 - 14999  Black  Female     High school  58  Never married
# 24292  $25000 or more  Black    Male     High school  40  Never married
# 24300  $25000 or more  White    Male        Bachelor  46       Divorced
# 24301  $25000 or more  White    Male     High school  55       Divorced
# 24314  $25000 or more  White  Female     High school  35  Never married
# 24315  $25000 or more  White  Female        Graduate  27        Married
# 24318  $20000 - 24999  White  Female  Junior college  44       Divorced
# 24319  $25000 or more  White    Male        Bachelor  60        Married
# 24320  $25000 or more  White    Male     High school  47        Married
# 24324  $25000 or more  White  Female        Graduate  66       Divorced
# 24325  $10000 - 14999  White    Male     High school  38        Married
# 24327  $20000 - 24999  White  Female     High school  24  Never married
# 24328  $20000 - 24999  White  Female     High school  49        Married
# 24330  $25000 or more  White  Female     High school  58        Married
# 24332  $20000 - 24999  White  Female     High school  34        Married
# 24334  $25000 or more  White    Male  Lt high school  40        Married
# 24336   $3000 to 3999  White    Male        Bachelor  40        Married
# 24339  $25000 or more  White  Female  Junior college  35      Separated
# 24348  $10000 - 14999  White  Female     High school  55        Married
#
#             Work Status    ID
# 0      Working fulltime     1
# 1      Working fulltime     2
# 5      Working fulltime     6
# 6      Working fulltime     7
# 7      Working fulltime     8
# 8      Working fulltime     9
# 11     Working fulltime    12
# 12     Working fulltime    13
# 13     Working fulltime    14
# 14     Unempl, laid off    15
# 18     Working fulltime    19
# 23        Keeping house    24
# 33     Working fulltime    34
# 34     Working fulltime    35
# 35     Working fulltime    36
# 38     Working fulltime    39
# 40     Working fulltime    41
# 41     Working fulltime    42
# 42     Unempl, laid off    43
# 45     Working fulltime    46
# 46     Working fulltime    47
# 48     Working fulltime    49
# 49     Working fulltime    50
# 50     Working fulltime    51
# 51     Working parttime    52
# 52     Working fulltime    53
# 54     Working parttime    55
# 56     Working fulltime    57
# 57     Working fulltime    58
# 58        Keeping house    59
# ...                 ...   ...
# 24238  Working fulltime  2756
# 24246  Working fulltime  2764
# 24249  Temp not working  2767
# 24257  Working fulltime  2775
# 24259  Working fulltime  2777
# 24268  Working fulltime  2786
# 24269  Working fulltime  2787
# 24270           Retired  2788
# 24271  Temp not working  2789
# 24279  Working fulltime  2797
# 24287  Working parttime  2805
# 24291     Keeping house  2809
# 24292  Working fulltime  2810
# 24300  Working fulltime  2818
# 24301  Working fulltime  2819
# 24314  Working fulltime  2832
# 24315  Working fulltime  2833
# 24318  Working fulltime  2836
# 24319  Working fulltime  2837
# 24320  Working fulltime  2838
# 24324  Working fulltime  2842
# 24325  Working fulltime  2843
# 24327  Working fulltime  2845
# 24328  Working parttime  2846
# 24330  Working fulltime  2848
# 24332  Working fulltime  2850
# 24334  Working fulltime  2852
# 24336  Working fulltime  2854
# 24339  Working fulltime  2857
# 24348  Working fulltime  2866
#
# [8150 rows x 12 columns]

# %%
dfclean8.dtypes
# Out:
# Year                  int64
# Health Condition     object
# General happiness     int64
# U.S. Region          object
# Income               object
# Race                 object
# Sex                  object
# Highest Degree       object
# Age                  object
# Marital status       object
# Work Status          object
# ID                    int64
# dtype: object

# %%
dfclean8.to_csv('gssCleanedData.csv', index=False)
